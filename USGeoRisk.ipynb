# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
#import visualizations as vz

# %%
#The data files and import into pandas dataFrames
epuFile = 'USEPU.csv'
gprFile = 'GPRdaily.csv'
crudeFile = 'CrudeOilFutures.csv'
usepu = pd.read_csv(epuFile,parse_dates = True,index_col = 'DATE')
gprData = pd.read_csv(gprFile,parse_dates = True,index_col = 'DATE')
gprData = gprData.drop(['DAY_NUMBERS','EVENT',
                        '*value of the index on the day the newspaper was published'],axis = 1)
crudeFutures = pd.read_csv(crudeFile,parse_dates = True,index_col = 'Date')
crudeFutures = crudeFutures.sort_index(ascending = True)
usepu.info()
print("\n")
gprData.info()
print("\n")
crudeFutures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 91 entries, 2020-01-01 to 2020-03-31
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   USEPUINDXD  91 non-null     float64
# dtypes: float64(1)
# memory usage: 1.4 KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12853 entries, 1985-01-01 to 2020-03-10
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   N11D               12853 non-null  int64
#  1   GPRD_RAW           12853 non-null  int64
#  2   GPRD_THREAT_RAW    12789 non-null  float64
#  3   GPRD_ACT_RAW       12789 non-null  float64
#  4   GPRD_SHARE         12853 non-null  object
#  5   GPRD_THREAT_SHARE  12789 non-null  object
#  6   GPRD_ACT_SHARE     12789 non-null  object
#  7   GPRD*              12853 non-null  int64
#  8   GPRD_THREAT        12789 non-null  float64
# ...

# %%
#Plot a few dataframes 
sns.set(rc={'figure.figsize':(11, 4)})
plt.figure()
plt.plot(usepu.index,usepu['USEPUINDXD'])
plt.grid(color = 'r')
plt.legend(loc = 'best')
#usepu['USEPUINDXD'].plot(linewidth = 2,grid = 1,legend = True)
plt.figure()
#gprData['GPRD_RAW'].plot(linewidth = 2,grid = 1,legend = True)
plt.figure()
#crudeFutures['Price'].plot(linewidth = 2,grid = 1,legend = True)
plt.show()
# Out:
# No handles with labels found to put in legend.
